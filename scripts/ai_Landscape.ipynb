# %% [markdown]
# # Belgian AI Landscape
#
# ## Part 1: Scraping and storing data
#
# ### 1. Import Modules

# %%
import time
import numpy as np
import pandas as pd
from scrapeData import scrape_pages_ai4belgium, extract_address_CBE, extract_address_google_search
from concurrent.futures import ThreadPoolExecutor

# %% [markdown]
# ### 2. Scrape company information from AI4Belgium

# %%
# Create a DataFrame from the AI4Belgium website and save as a DataFrame
ai_df = scrape_pages_ai4belgium()
# Out:
# https://community.ai4belgium.be/en/ai-landscape?nav=0&page=1
# Setting up WebDriver...
# Navigating to https://community.ai4belgium.be/en/ai-landscape?nav=0&page=1
# No GDPR cookie banner found! Continue ...
# Attempting to locate and switch to the iframe...
# ✅ Found the company item element(s)! Count: 25
# Warning: Could not fully extract data from image.
# https://community.ai4belgium.be/en/ai-landscape?nav=0&page=2
# Setting up WebDriver...
# Navigating to https://community.ai4belgium.be/en/ai-landscape?nav=0&page=2
# No GDPR cookie banner found! Continue ...
# Attempting to locate and switch to the iframe...
# ✅ Found the company item element(s)! Count: 25
# https://community.ai4belgium.be/en/ai-landscape?nav=0&page=3
# Setting up WebDriver...
# Navigating to https://community.ai4belgium.be/en/ai-landscape?nav=0&page=3
# No GDPR cookie banner found! Continue ...
# Attempting to locate and switch to the iframe...
# ✅ Found the company item element(s)! Count: 25
# Warning: Could not fully extract data from image.
# Warning: Could not fully extract data from image.
# Warning: Could not fully extract data from image.
# Warning: Could not fully extract data from image.
# Warning: Could not fully extract data from image.
# https://community.ai4belgium.be/en/ai-landscape?nav=0&page=4
# Setting up WebDriver...
# Navigating to https://community.ai4belgium.be/en/ai-landscape?nav=0&page=4
# No GDPR cookie banner found! Continue ...
# Attempting to locate and switch to the iframe...
# ✅ Found the company item element(s)! Count: 25
# Warning: Could not fully extract data from image.
# Warning: Could not fully extract data from image.
# https://community.ai4belgium.be/en/ai-landscape?nav=0&page=5
# Setting up WebDriver...
# Navigating to https://community.ai4belgium.be/en/ai-landscape?nav=0&page=5
# No GDPR cookie banner found! Continue ...
# Attempting to locate and switch to the iframe...
# ✅ Found the company item element(s)! Count: 25
# Warning: Could not fully extract data from image.
# https://community.ai4belgium.be/en/ai-landscape?nav=0&page=6
# Setting up WebDriver...
# Navigating to https://community.ai4belgium.be/en/ai-landscape?nav=0&page=6
# No GDPR cookie banner found! Continue ...
# Attempting to locate and switch to the iframe...
# ✅ Found the company item element(s)! Count: 25
# Warning: Could not fully extract data from image.
# Warning: Could not fully extract data from image.
# https://community.ai4belgium.be/en/ai-landscape?nav=0&page=7
# Setting up WebDriver...
# Navigating to https://community.ai4belgium.be/en/ai-landscape?nav=0&page=7
# No GDPR cookie banner found! Continue ...
# Attempting to locate and switch to the iframe...
# ✅ Found the company item element(s)! Count: 25
# https://community.ai4belgium.be/en/ai-landscape?nav=0&page=8
# Setting up WebDriver...
# Navigating to https://community.ai4belgium.be/en/ai-landscape?nav=0&page=8
# No GDPR cookie banner found! Continue ...
# Attempting to locate and switch to the iframe...
# ✅ Found the company item element(s)! Count: 25
# Warning: Could not fully extract data from image.
# Warning: Could not fully extract data from image.
# https://community.ai4belgium.be/en/ai-landscape?nav=0&page=9
# Setting up WebDriver...
# Navigating to https://community.ai4belgium.be/en/ai-landscape?nav=0&page=9
# No GDPR cookie banner found! Continue ...
# Attempting to locate and switch to the iframe...
# ✅ Found the company item element(s)! Count: 25
# Warning: Could not fully extract data from image.
# Warning: Could not fully extract data from image.
# https://community.ai4belgium.be/en/ai-landscape?nav=0&page=10
# Setting up WebDriver...
# Navigating to https://community.ai4belgium.be/en/ai-landscape?nav=0&page=10
# No GDPR cookie banner found! Continue ...
# Attempting to locate and switch to the iframe...
# ✅ Found the company item element(s)! Count: 25
# Warning: Could not fully extract data from image.
# Warning: Could not fully extract data from image.
# Warning: Could not fully extract data from image.
# Warning: Could not fully extract data from image.
# Warning: Could not fully extract data from image.
# https://community.ai4belgium.be/en/ai-landscape?nav=0&page=11
# Setting up WebDriver...
# Navigating to https://community.ai4belgium.be/en/ai-landscape?nav=0&page=11
# No GDPR cookie banner found! Continue ...
# Attempting to locate and switch to the iframe...
# ✅ Found the company item element(s)! Count: 25
# Warning: Could not fully extract data from image.
# https://community.ai4belgium.be/en/ai-landscape?nav=0&page=12
# Setting up WebDriver...
# Navigating to https://community.ai4belgium.be/en/ai-landscape?nav=0&page=12
# No GDPR cookie banner found! Continue ...
# Attempting to locate and switch to the iframe...
# ✅ Found the company item element(s)! Count: 25
# Warning: Could not fully extract data from image.
# Warning: Could not fully extract data from image.
# https://community.ai4belgium.be/en/ai-landscape?nav=0&page=13
# Setting up WebDriver...
# Navigating to https://community.ai4belgium.be/en/ai-landscape?nav=0&page=13
# No GDPR cookie banner found! Continue ...
# Attempting to locate and switch to the iframe...
# ✅ Found the company item element(s)! Count: 25
# https://community.ai4belgium.be/en/ai-landscape?nav=0&page=14
# Setting up WebDriver...
# Navigating to https://community.ai4belgium.be/en/ai-landscape?nav=0&page=14
# No GDPR cookie banner found! Continue ...
# Attempting to locate and switch to the iframe...
# ✅ Found the company item element(s)! Count: 25
# Warning: Could not fully extract data from image.
# Warning: Could not fully extract data from image.
# https://community.ai4belgium.be/en/ai-landscape?nav=0&page=15
# Setting up WebDriver...
# Navigating to https://community.ai4belgium.be/en/ai-landscape?nav=0&page=15
# No GDPR cookie banner found! Continue ...
# Attempting to locate and switch to the iframe...
# ✅ Found the company item element(s)! Count: 25
# Warning: Could not fully extract data from image.
# https://community.ai4belgium.be/en/ai-landscape?nav=0&page=16
# Setting up WebDriver...
# Navigating to https://community.ai4belgium.be/en/ai-landscape?nav=0&page=16
# No GDPR cookie banner found! Continue ...
# Attempting to locate and switch to the iframe...
# ✅ Found the company item element(s)! Count: 25
# Warning: Could not fully extract data from image.
# https://community.ai4belgium.be/en/ai-landscape?nav=0&page=17
# Setting up WebDriver...
# Navigating to https://community.ai4belgium.be/en/ai-landscape?nav=0&page=17
# No GDPR cookie banner found! Continue ...
# Attempting to locate and switch to the iframe...
# ✅ Found the company item element(s)! Count: 25
# Warning: Could not fully extract data from image.
# https://community.ai4belgium.be/en/ai-landscape?nav=0&page=18
# Setting up WebDriver...
# Navigating to https://community.ai4belgium.be/en/ai-landscape?nav=0&page=18
# No GDPR cookie banner found! Continue ...
# Attempting to locate and switch to the iframe...
# ✅ Found the company item element(s)! Count: 0

# %%
ai_df.head()
# Out:
#        name                      url  \
# 0   6Wolves   http://www.6wolves.ai/
# 1  ActiveMe      http://activeme.be/
# 2    Adshot        http://adshot.io/
# 3    Adunio      http://www.adun.io/
# 4  Agilytic  http://www.agilytic.be/
#
#                                                 logo  \
# 0  https://community.ai4belgium.be/ai-landscape//...
# 1  https://community.ai4belgium.be/ai-landscape//...
# 2  https://community.ai4belgium.be/ai-landscape//...
# 3  https://community.ai4belgium.be/ai-landscape//...
# 4  https://community.ai4belgium.be/ai-landscape//...
#
#                                           categories creation date    region
# 0                               Healthcare & biotech          2019  Brussels
# 1  Social (Education, Civic Tech, Entertainment, ...          2012  Wallonia
# 2                           Image & video processing          2016  Flanders
# 3                                  Sales & Marketing          2019  Flanders
# 4                                           Services          2015  Wallonia

# %% [markdown]
# ### 3. Search for company address
#
#     Note: Here we use threading to speed-up our code.

# %%
ai_df = pd.read_csv("../data/raw_scraped_dataset.csv")

# 1. Apply the function to the 'name' column, resulting in a Series of tuples.
results_series = ai_df['name'].apply(extract_address_CBE)

# 2. Convert the Series of tuples into a DataFrame and assign column names.
new_cols_df = results_series.apply(pd.Series)
new_cols_df.columns = ["street", "zip_code", "city"]

# 3. Concatenate the new columns to the original DataFrame.
ai_df = pd.concat([ai_df, new_cols_df], axis=1)

# %%
display(ai_df.head(10))
# Out:
#             name                       url  \
# 0        6Wolves    http://www.6wolves.ai/
# 1       ActiveMe       http://activeme.be/
# 2         Adshot         http://adshot.io/
# 3         Adunio       http://www.adun.io/
# 4       Agilytic   http://www.agilytic.be/
# 5       Aividens  http://www.aividens.com/
# 6        Alberts        http://alberts.be/
# 7  Allthingsblue  http://allthingsblue.eu/
# 8       AlterEdu   http://www.alteredu.be/
# 9        Amethix       http://amethix.com/
#
#                                                 logo  \
# 0  https://community.ai4belgium.be/ai-landscape//...
# 1  https://community.ai4belgium.be/ai-landscape//...
# 2  https://community.ai4belgium.be/ai-landscape//...
# 3  https://community.ai4belgium.be/ai-landscape//...
# 4  https://community.ai4belgium.be/ai-landscape//...
# 5  https://community.ai4belgium.be/ai-landscape//...
# 6  https://community.ai4belgium.be/ai-landscape//...
# 7  https://community.ai4belgium.be/ai-landscape//...
# 8  https://community.ai4belgium.be/ai-landscape//...
# 9  https://community.ai4belgium.be/ai-landscape//...
#
#                                           categories  creation date    region  \
# 0                               Healthcare & biotech         2019.0  Brussels
# 1  Social (Education, Civic Tech, Entertainment, ...         2012.0  Wallonia
# 2                           Image & video processing         2016.0  Flanders
# 3                                  Sales & Marketing         2019.0  Flanders
# 4                                           Services         2015.0  Wallonia
# 5                                    Legal & FinTech         2019.0  Brussels
# 6                       Agritech, Cleantech & energy         2015.0  Flanders
# 7                                        HR & Skills         2019.0  Flanders
# 8                                        HR & Skills         2019.0  Flanders
# 9                  RPA, Internal Data & Intelligence         2017.0  Flanders
#
#                       street zip_code                        city
# 0                       None     None                        None
# 1                 Granbonpré     1348  Ottignies-Louvain-la-Neuve
# 2                       None     None                        None
# 3     Luchthavenlaan 27 / 56     1800                   Vilvoorde
# 4        Clos de Rambouillet     1410                    Waterloo
# 5  Avenue des Volontaires 19     1160                   Auderghem
# 6          Nerviërsstraat 49     1730                        Asse
# 7                       None     None                        None
# 8          Eliaertsstraat 32     2140                   Antwerpen
# 9   Rue de l'Enseignement 25     1000                   Bruxelles

# %%
na_df = ai_df[ai_df["street"].isna()]
print(f"Address information missing for {round(len(na_df)/len(ai_df),2)*100}% records.")
display(na_df)
# Out:
# Address information missing for 24.0% records.
#                  name                           url  \
# 0             6Wolves        http://www.6wolves.ai/
# 2              Adshot             http://adshot.io/
# 7       Allthingsblue      http://allthingsblue.eu/
# 10       AMIA Systems  http://www.amia-systems.com/
# 11            Amigrow   https://amigrowfarming.com/
# ..                ...                           ...
# 381          VeriFlix    http://www.veriflix.ai/en/
# 386             WEPOC             https://wepoc.be/
# 389      AI Blackbelt  https://www.aiblackbelt.com/
# 390  La Scientotheque   https://lascientotheque.be/
# 395         Humain.AI             http://humain.ai/
#
#                                                   logo  \
# 0    https://community.ai4belgium.be/ai-landscape//...
# 2    https://community.ai4belgium.be/ai-landscape//...
# 7    https://community.ai4belgium.be/ai-landscape//...
# 10   https://community.ai4belgium.be/ai-landscape//...
# 11   https://community.ai4belgium.be/ai-landscape//...
# ..                                                 ...
# 381  https://community.ai4belgium.be/ai-landscape//...
# 386  https://community.ai4belgium.be/ai-landscape//...
# 389  https://community.ai4belgium.be/ai-landscape//...
# 390  https://community.ai4belgium.be/ai-landscape//...
# 395  https://community.ai4belgium.be/ai-landscape//...
#
#                                             categories  creation date  \
# 0                                 Healthcare & biotech         2019.0
# 2                             Image & video processing         2016.0
# 7                                          HR & Skills         2019.0
# 10                                          Industrial         2014.0
# 11                        Agritech, Cleantech & energy         2018.0
# ..                                                 ...            ...
# 381                           Image & video processing         2016.0
# 386                                           Services         2019.0
# 389  Social (Education, Civic Tech, Entertainment, ...         2018.0
# 390  Social (Education, Civic Tech, Entertainment, ...            NaN
# 395                                           Services         2019.0
#
#        region street zip_code  city
# 0    Brussels   None     None  None
# 2    Flanders   None     None  None
# 7    Flanders   None     None  None
# 10   Brussels   None     None  None
# 11   Flanders   None     None  None
# ..        ...    ...      ...   ...
# 381  Wallonia   None     None  None
# 386  Wallonia   None     None  None
# 389  Brussels   None     None  None
# 390  Brussels   None     None  None
# 395  Flanders   None     None  None
#
# [95 rows x 9 columns]

# %% [markdown]
# We will drop the missing data for now and save as our clean CSV.

# %%
final_df = ai_df.dropna()
print(f'Final dataset Size: {len(final_df)} companies.')
final_df.to_csv("../data/clean_scraped_dataset.csv", index = False)
# Out:
# Final dataset Size: 279 companies.

# %% [markdown]
# ### 5. Next Steps
#
# 1. Automate filling in missing values. Idea: Check other websites for scraping.
# 2. Visualize gathered data in a map.
# 3. Create Streamlit App and deploy.

# %% [markdown]
# To address the missing values, we opted to manually input the missing addresses while working on automating this process.
#
# To get our data ready for our app, we wanted to preprocess the addresses to also extract the zipcode and city as separate columns for further filtering.
#
# ## Part II: Visualizing

# %%
import pandas as pd
from geocodeAddress import create_address_column, geocode_address

final_df = pd.read_csv("../data/clean_scraped_dataset.csv")

# 1. Apply the function to the 'name' column, resulting in a Series of tuples.
final_df = create_address_column(final_df)
geocoded_address_series = final_df['address'].apply(geocode_address)


# 2. Convert the Series of tuples into a DataFrame and assign column names.
new_cols_df = geocoded_address_series.apply(pd.Series)
new_cols_df.columns = ["lat", "lon"]

# 3. Concatenate the new columns to the original DataFrame.
geocoded_df = pd.concat([final_df, new_cols_df], axis=1)

# %%
geocoded_df.to_csv("../data/geocoded_dataset.csv", index = False)
display(geocoded_df.head())
# Out:
#        name                       url  \
# 0  ActiveMe       http://activeme.be/
# 1    Adunio       http://www.adun.io/
# 2  Agilytic   http://www.agilytic.be/
# 3  Aividens  http://www.aividens.com/
# 4   Alberts        http://alberts.be/
#
#                                                 logo  \
# 0  https://community.ai4belgium.be/ai-landscape//...
# 1  https://community.ai4belgium.be/ai-landscape//...
# 2  https://community.ai4belgium.be/ai-landscape//...
# 3  https://community.ai4belgium.be/ai-landscape//...
# 4  https://community.ai4belgium.be/ai-landscape//...
#
#                                           categories  creation date    region  \
# 0  Social (Education, Civic Tech, Entertainment, ...         2012.0  Wallonia
# 1                                  Sales & Marketing         2019.0  Flanders
# 2                                           Services         2015.0  Wallonia
# 3                                    Legal & FinTech         2019.0  Brussels
# 4                       Agritech, Cleantech & energy         2015.0  Flanders
#
#                       street zip_code                        city  \
# 0                 Granbonpré     1348  Ottignies-Louvain-la-Neuve
# 1     Luchthavenlaan 27 / 56     1800                   Vilvoorde
# 2        Clos de Rambouillet     1410                    Waterloo
# 3  Avenue des Volontaires 19     1160                   Auderghem
# 4          Nerviërsstraat 49     1730                        Asse
#
#                                       address        lat       lon
# 0  Granbonpré 1348 Ottignies-Louvain-la-Neuve  50.663890  4.638767
# 1       Luchthavenlaan 27 / 56 1800 Vilvoorde  50.922049  4.443258
# 2           Clos de Rambouillet 1410 Waterloo  50.727426  4.388866
# 3    Avenue des Volontaires 19 1160 Auderghem  50.826944  4.404133
# 4                 Nerviërsstraat 49 1730 Asse  50.916292  4.189980

# %%
#Test interactive map function
import pandas as pd
from interactiveMap import get_location_interactive

geocoded_df = pd.read_csv("../data/geocoded_dataset.csv")
get_location_interactive(geocoded_df)
